# %%
import torch
import cv2

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
get_ipython().run_line_magic('matplotlib', 'inline')

import matplotlib.image as mpimg
from matplotlib import font_manager, rc
rc('font',family="AppleGothic")
plt.rcParams["font.family"]="AppleGothic" #plt 한글꺠짐
plt.rcParams["font.family"]="Arial" #외국어꺠짐
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정
plt.rc('figure', figsize=(10,8))

sns.set(font="AppleGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid') #sns 한글깨짐


torch.cuda.is_available()

# %%
def show(img):
    #사이즈
    plt.figure(figsize = (10,8))
    #xticks/yticks - 눈금표
    plt.xticks([])
    plt.yticks([])
    #코랩에서 안돌아감 주의
    plt.imshow(img, cmap= 'gray')
    plt.show()

def vid_info(path, codec, name, fps):
    cap = cv2.VideoCapture(path)
    print(cap)
    width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)

    #재생할 파일의 높이 얻기
    height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
    #재생할 파일의 프레임 레이트 얻기
    # fps = cap.get(cv2.CAP_PROP_FPS)
    
    #codec
    fourcc = cv2.VideoWriter_fourcc(*codec)
    
    #filename
    filename = name+'.mp4'
    
    #out 
    out = cv2.VideoWriter(filename, fourcc, fps, (int(width), int(height)))
    
    print('cap {0}, width {1}, height {2}, fps {3}'.format(cap, width, height, fps))
    print('codec {0}', 'filename {1}'.format(fourcc, filename))
    
    return cap, width, height, fps, fourcc, filename, out

# %%
vid = "C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\basic.mp4"

# %%
cap, width, height, fps, fourcc, filename, out = vid_info(vid, 'XVID','test_test2', 60)

# %%
img_list =[]

vid = "C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\basic.mp4"
cap, width, height, fps, fourcc, filename, out = vid_info(vid, 'XVID','test_test2', 60)

while True:
    # show(blank_img)
    ret, org_frame = cap.read()
    
    if not ret:
        break
    ####### keypoint ######
    frame = org_frame.copy()
    frame = frame[0:720, 770:1280]
    # frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    cv2.imshow('frame',frame)
    img_list.append(frame)

    if cv2.waitKey(30) == 27:
        break


cap.release()
out.release()

cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
vid = "C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\원본\\철도모형 운행 영상\\기본.mp4"
cap, width, height, fps, fourcc, filename, out = vid_info(vid, 'XVID','test_test2', 60)


while True:
    # show(blank_img)
    ret, org_frame = cap.read()
    
    if not ret:
        break
    ####### keypoint ######
    frame = org_frame.copy()
    frame = frame[0:720, 770:1280]
    # frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    cv2.imshow('frame',frame)


    if cv2.waitKey(30) == 27:
        break


cap.release()
out.release()

cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
vid = "C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\test_set\\기본.mp4"
cap = cv2.VideoCapture(vid)

# %cd C:\Users\yukir\Documents\Monicas_workspace\train_diff\workspace\yolov7-custom

img_list =[]

while True:
    # show(blank_img)
    ret, org_frame = cap.read()
    
    if not ret:
        break
    ####### keypoint ######
    frame = org_frame.copy()
    print(frame.shape)
    frame = frame[0:720, 770:1280]
    img_list.append(frame)
    # frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    # !python detect.py --weights best_v1.pt --conf 0.4 --source C:\Users\yukir\Documents\Monicas_workspace\train_diff\원본\철도모형 운행 영상\위치변경.mp4
    cv2.imshow('frame',frame)
    

    if cv2.waitKey(30) == 27:
        break


cap.release()
out.release()

cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
 # !python detect.py --weights best_v1.pt --conf 0.4 --source C:\Users\yukir\Documents\Monicas_workspace\train_diff\test_set\basic.mp4

# %%
# %cd C:\Users\yukir\Documents\Monicas_workspace\train_diff\workspace

# %%
vid = "C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\test_set\\basic.mp4"
save_path = "C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\workspace\\yolov7-custom\\frame\\"

h = 720
w = 510
fps = cap.get(cv2.CAP_PROP_FPS)
fourcc = cv2.VideoWriter_fourcc(*'DIVX')
out = cv2.VideoWriter('output.mp4', fourcc, fps, (w, h))

num = 0

while True:
    # show(blank_img)
    ret, org_frame = cap.read()
    
    if not ret:
        break
    ####### keypoint ######
    frame = org_frame.copy()
    frame = frame[0:720, 770:1280]
    num+=1

    cv2.imwrite(save_path+'{}.jpg'.format(num), frame)
    
    # out.write(frame)
    # cv2.imshow('frame',frame)

    if cv2.waitKey(30) == 27:
        break


cap.release()
# out.release()

cv2.destroyAllWindows()
cv2.waitKey(1)

# !python detect.py --weights best_v1.pt --conf 0.5 --source frame

# %% [markdown]
# ### Similarity

# %%
vid = "C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\basic.mp4"

# %%
cap = cv2.VideoCapture("C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\org\\testing_vid\\basic.mp4")

#재생할 파일의 넓이 얻기
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)

#재생할 파일의 높이 얻기
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
#재생할 파일의 프레임 레이트 얻기
fps = cap.get(cv2.CAP_PROP_FPS)

print('width {0}, height {1}, fps {2}'.format(width, height, fps))

#저장할 비디오 코덱
fourcc = cv2.VideoWriter_fourcc(*'XVID')
#저장할 파일 이름
filename = 'detection_result_test.mp4'

# #파일 stream 생성
out = cv2.VideoWriter(filename, fourcc, fps, (int(width), int(height)))
# out = cv2.VideoWriter(filename, fourcc, fps, (int(width), int(height)))


if not cap.isOpened():
    print('Video open failed!')
    sys.exit()

# 배경 영상 등록
ret, back = cap.read()

if not ret:
    print('Background image registration failed!')
    sys.exit()
    
# 연산 속도를 높이기 위해 그레이스케일 영상으로 변환
back = cv2.cvtColor(back, cv2.COLOR_BGR2GRAY)

# 가우시안 블러로 노이즈 제거 (모폴로지, 열기, 닫기 연산도 가능)
back = cv2.GaussianBlur(back, (0, 0), 1.0)

# 비디오 매 프레임 처리
test_list =[]
frame_num = 0 
k = 0

while k <= 600:
    ret, frame = cap.read()
    
    if not ret:
        break
    frame_num +=1 
    # 현재 프레임 영상 그레이스케일 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # 노이즈 제거
    gray = cv2.GaussianBlur(gray, (0, 0), 1.0)
    
    # 차영상 구하기 $ 이진화
    # absdiff는 차 영상에 절대값
    diff = cv2.absdiff(gray, back)
    # gray_mean() or 밝기정도 지정 가능
    ####!!!!!back.mean()으로 하면 smoke까지 가능?
    _, diff = cv2.threshold(diff, 70, 255, cv2.THRESH_BINARY)
    
    # 레이브링을 이용하여 바운딩 박스 표시
    cnt, _, stats, _ = cv2.connectedComponentsWithStats(diff)
    
    #contour
#     dilated = cv2.dilate(diff, None, iteration=3)

    contours, _ = cv2.findContours(diff, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    cv2.putText(frame, "frame num : {}".format(frame_num), (30,700),cv2.FONT_HERSHEY_SIMPLEX,
                   1, (255,0,0),3)
    # check_img = frame.copy()
    for i in range(1, cnt):
        x, y, w, h, s = stats[i]
        check_img = frame.copy()
        if s < 10:
            continue
        
        # cv2.drawContours(frame, contours, -1, (0, 0, 255),2)
        
        # print(frame_num)
        cv2.rectangle(frame, (x, y, w, h), (0, 255, 0), 2)
        cv2.putText(frame, "MOTION DETECTED", (30,60),cv2.FONT_HERSHEY_SIMPLEX,
                   1, (0,0,255),3)
        k +=1    
        print(k)
    
    cv2.imshow('frame', frame)
    out.write(frame)

    if cv2.waitKey(30) == 27:
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture("C:\\Users\\yukir\\Documents\\Monicas_workspace\\train_diff\\org\\testing_vid\\location.mp4")

#재생할 파일의 넓이 얻기
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)

#재생할 파일의 높이 얻기
height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
#재생할 파일의 프레임 레이트 얻기
fps = cap.get(cv2.CAP_PROP_FPS)

print('width {0}, height {1}, fps {2}'.format(width, height, fps))

#저장할 비디오 코덱
fourcc = cv2.VideoWriter_fourcc(*'XVID')
#저장할 파일 이름
filename = 'detection_result_test.mp4'

# #파일 stream 생성
out = cv2.VideoWriter(filename, fourcc, fps, (int(width), int(height)))
# out = cv2.VideoWriter(filename, fourcc, fps, (int(width), int(height)))


if not cap.isOpened():
    print('Video open failed!')
    sys.exit()

# 배경 영상 등록
ret, back = cap.read()

if not ret:
    print('Background image registration failed!')
    sys.exit()
    
# 연산 속도를 높이기 위해 그레이스케일 영상으로 변환
back = cv2.cvtColor(back, cv2.COLOR_BGR2GRAY)

# 가우시안 블러로 노이즈 제거 (모폴로지, 열기, 닫기 연산도 가능)
back = cv2.GaussianBlur(back, (0, 0), 1.0)

# 비디오 매 프레임 처리
test_list_2 =[]
frame_num = 0 
while True:
    ret, frame = cap.read()
    
    if not ret:
        break
    frame_num +=1 
    # 현재 프레임 영상 그레이스케일 변환
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # 노이즈 제거
    gray = cv2.GaussianBlur(gray, (0, 0), 1.0)
    
    # 차영상 구하기 $ 이진화
    # absdiff는 차 영상에 절대값
    diff = cv2.absdiff(gray, back)
    # gray_mean() or 밝기정도 지정 가능
    ####!!!!!back.mean()으로 하면 smoke까지 가능?
    _, diff = cv2.threshold(diff, 70, 255, cv2.THRESH_BINARY)
    
    # 레이브링을 이용하여 바운딩 박스 표시
    cnt, _, stats, _ = cv2.connectedComponentsWithStats(diff)
    
    #contour
#     dilated = cv2.dilate(diff, None, iteration=3)

    contours, _ = cv2.findContours(diff, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    cv2.putText(frame, "frame num : {}".format(frame_num), (30,700),cv2.FONT_HERSHEY_SIMPLEX,
                   1, (255,0,0),3)
    # check_img = frame.copy()
    for i in range(1, cnt):
        x, y, w, h, s = stats[i]
        check_img = frame.copy()
        if s < 10:
            continue
        
        # cv2.drawContours(frame, contours, -1, (0, 0, 255),2)
        
        # print(frame_num)
        cv2.rectangle(frame, (x, y, w, h), (0, 255, 0), 2)
        cv2.putText(frame, "MOTION DETECTED", (30,60),cv2.FONT_HERSHEY_SIMPLEX,
                   1, (0,0,255),3)
    
        
        test_list_2.append(frame)
        if frame_num == frame_num+64:
            break

    
    cv2.imshow('frame', frame)
    out.write(frame)

    if cv2.waitKey(30) == 27:
        break

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
for num, i in enumerate(test_list):
    if num<2:
        show(i)
    elif num==3:
        break

# %%
len(test_list_2)

# %%
show(test_list_2[0])

# %%
258-194

# %%
show(test_list_2[900])

# %%
for num, i in enumerate(test_list_2):
    if num<2:
        show(i)
    elif num==3:
        break
